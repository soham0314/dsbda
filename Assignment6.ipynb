# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('https://raw.githubusercontent.com/mk-gurucharan/Classification/master/IrisDataset.csv')

# %%
dataset.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
dataset.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
dataset.shape
# Out:
# (150, 5)

# %%
X = dataset.iloc[:,:4].values

# %%
X
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
#        [5.2, 4.1, 1.5, 0.1],
#        [5.5, 4.2, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5. , 3.2, 1.2, 0.2],
#        [5.5, 3.5, 1.3, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [4.4, 3. , 1.3, 0.2],
#        [5.1, 3.4, 1.5, 0.2],
#        [5. , 3.5, 1.3, 0.3],
#        [4.5, 2.3, 1.3, 0.3],
#        [4.4, 3.2, 1.3, 0.2],
#        [5. , 3.5, 1.6, 0.6],
#        [5.1, 3.8, 1.9, 0.4],
#        [4.8, 3. , 1.4, 0.3],
#        [5.1, 3.8, 1.6, 0.2],
#        [4.6, 3.2, 1.4, 0.2],
#        [5.3, 3.7, 1.5, 0.2],
#        [5. , 3.3, 1.4, 0.2],
#        [7. , 3.2, 4.7, 1.4],
#        [6.4, 3.2, 4.5, 1.5],
#        [6.9, 3.1, 4.9, 1.5],
#        [5.5, 2.3, 4. , 1.3],
#        [6.5, 2.8, 4.6, 1.5],
#        [5.7, 2.8, 4.5, 1.3],
#        [6.3, 3.3, 4.7, 1.6],
#        [4.9, 2.4, 3.3, 1. ],
#        [6.6, 2.9, 4.6, 1.3],
#        [5.2, 2.7, 3.9, 1.4],
#        [5. , 2. , 3.5, 1. ],
#        [5.9, 3. , 4.2, 1.5],
#        [6. , 2.2, 4. , 1. ],
#        [6.1, 2.9, 4.7, 1.4],
#        [5.6, 2.9, 3.6, 1.3],
#        [6.7, 3.1, 4.4, 1.4],
#        [5.6, 3. , 4.5, 1.5],
#        [5.8, 2.7, 4.1, 1. ],
#        [6.2, 2.2, 4.5, 1.5],
#        [5.6, 2.5, 3.9, 1.1],
#        [5.9, 3.2, 4.8, 1.8],
#        [6.1, 2.8, 4. , 1.3],
#        [6.3, 2.5, 4.9, 1.5],
#        [6.1, 2.8, 4.7, 1.2],
#        [6.4, 2.9, 4.3, 1.3],
#        [6.6, 3. , 4.4, 1.4],
#        [6.8, 2.8, 4.8, 1.4],
#        [6.7, 3. , 5. , 1.7],
#        [6. , 2.9, 4.5, 1.5],
#        [5.7, 2.6, 3.5, 1. ],
#        [5.5, 2.4, 3.8, 1.1],
#        [5.5, 2.4, 3.7, 1. ],
#        [5.8, 2.7, 3.9, 1.2],
#        [6. , 2.7, 5.1, 1.6],
#        [5.4, 3. , 4.5, 1.5],
#        [6. , 3.4, 4.5, 1.6],
#        [6.7, 3.1, 4.7, 1.5],
#        [6.3, 2.3, 4.4, 1.3],
#        [5.6, 3. , 4.1, 1.3],
#        [5.5, 2.5, 4. , 1.3],
#        [5.5, 2.6, 4.4, 1.2],
#        [6.1, 3. , 4.6, 1.4],
#        [5.8, 2.6, 4. , 1.2],
#        [5. , 2.3, 3.3, 1. ],
#        [5.6, 2.7, 4.2, 1.3],
#        [5.7, 3. , 4.2, 1.2],
#        [5.7, 2.9, 4.2, 1.3],
#        [6.2, 2.9, 4.3, 1.3],
#        [5.1, 2.5, 3. , 1.1],
#        [5.7, 2.8, 4.1, 1.3],
#        [6.3, 3.3, 6. , 2.5],
#        [5.8, 2.7, 5.1, 1.9],
#        [7.1, 3. , 5.9, 2.1],
#        [6.3, 2.9, 5.6, 1.8],
#        [6.5, 3. , 5.8, 2.2],
#        [7.6, 3. , 6.6, 2.1],
#        [4.9, 2.5, 4.5, 1.7],
#        [7.3, 2.9, 6.3, 1.8],
#        [6.7, 2.5, 5.8, 1.8],
#        [7.2, 3.6, 6.1, 2.5],
#        [6.5, 3.2, 5.1, 2. ],
#        [6.4, 2.7, 5.3, 1.9],
#        [6.8, 3. , 5.5, 2.1],
#        [5.7, 2.5, 5. , 2. ],
#        [5.8, 2.8, 5.1, 2.4],
#        [6.4, 3.2, 5.3, 2.3],
#        [6.5, 3. , 5.5, 1.8],
#        [7.7, 3.8, 6.7, 2.2],
#        [7.7, 2.6, 6.9, 2.3],
#        [6. , 2.2, 5. , 1.5],
#        [6.9, 3.2, 5.7, 2.3],
#        [5.6, 2.8, 4.9, 2. ],
#        [7.7, 2.8, 6.7, 2. ],
#        [6.3, 2.7, 4.9, 1.8],
#        [6.7, 3.3, 5.7, 2.1],
#        [7.2, 3.2, 6. , 1.8],
#        [6.2, 2.8, 4.8, 1.8],
#        [6.1, 3. , 4.9, 1.8],
#        [6.4, 2.8, 5.6, 2.1],
#        [7.2, 3. , 5.8, 1.6],
#        [7.4, 2.8, 6.1, 1.9],
#        [7.9, 3.8, 6.4, 2. ],
#        [6.4, 2.8, 5.6, 2.2],
#        [6.3, 2.8, 5.1, 1.5],
#        [6.1, 2.6, 5.6, 1.4],
#        [7.7, 3. , 6.1, 2.3],
#        [6.3, 3.4, 5.6, 2.4],
#        [6.4, 3.1, 5.5, 1.8],
#        [6. , 3. , 4.8, 1.8],
#        [6.9, 3.1, 5.4, 2.1],
#        [6.7, 3.1, 5.6, 2.4],
#        [6.9, 3.1, 5.1, 2.3],
#        [5.8, 2.7, 5.1, 1.9],
#        [6.8, 3.2, 5.9, 2.3],
#        [6.7, 3.3, 5.7, 2.5],
#        [6.7, 3. , 5.2, 2.3],
#        [6.3, 2.5, 5. , 1.9],
#        [6.5, 3. , 5.2, 2. ],
#        [6.2, 3.4, 5.4, 2.3],
#        [5.9, 3. , 5.1, 1.8]])

# %%
y = dataset['species'].values
y
# Out:
# array(['setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'virginica', 'virginica',
#        'virginica', 'virginica', 'virginica', 'virginica', 'virginica',
#        'virginica', 'virginica', 'virginica', 'virginica', 'virginica',
#        'virginica', 'virginica', 'virginica', 'virginica', 'virginica',
#        'virginica', 'virginica', 'virginica', 'virginica', 'virginica',
#        'virginica', 'virginica', 'virginica', 'virginica', 'virginica',
#        'virginica', 'virginica', 'virginica', 'virginica', 'virginica',
#        'virginica', 'virginica', 'virginica', 'virginica', 'virginica',
#        'virginica', 'virginica', 'virginica', 'virginica', 'virginica',
#        'virginica', 'virginica', 'virginica', 'virginica', 'virginica',
#        'virginica', 'virginica', 'virginica'], dtype=object)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
X_train
# Out:
# array([[ 0.19406156, -0.82722623,  0.78087748,  0.54778974],
#        [-1.1195859 , -0.15950999, -1.29274453, -1.27095881],
#        [ 2.22424398, -0.60465415,  1.67757888,  1.06743219],
#        [ 1.14944152, -0.15950999,  1.00505283,  1.1973428 ],
#        [-0.52247342,  1.39849456, -1.23670069, -1.27095881],
#        [-0.40305092, -1.49494246,  0.05230758, -0.10176331],
#        [-0.88074091,  0.9533504 , -1.29274453, -1.1410482 ],
#        [-0.76131841,  2.28878288, -1.23670069, -1.40086942],
#        [ 1.03001903,  0.50820625,  1.1171405 ,  1.1973428 ],
#        [ 0.67175154, -0.38208207,  0.33252677,  0.15805791],
#        [ 1.03001903, -0.15950999,  0.83692131,  1.45716402],
#        [-0.52247342,  0.73077833, -1.23670069, -1.01113759],
#        [-0.28362843, -0.38208207, -0.05978009,  0.15805791],
#        [-0.04478344,  2.0662108 , -1.4048322 , -1.27095881],
#        [-0.28362843, -0.15950999,  0.2204391 ,  0.15805791],
#        [-1.0001634 ,  0.9533504 , -1.18065685, -0.75131637],
#        [ 0.07463906,  0.28563417,  0.61274596,  0.80761096],
#        [-0.28362843, -0.15950999,  0.44461445,  0.41787913],
#        [-0.04478344, -0.82722623,  0.78087748,  0.93752157],
#        [-1.71669838,  0.28563417, -1.34878837, -1.27095881],
#        [-0.04478344, -0.60465415,  0.78087748,  1.58707463],
#        [-1.0001634 ,  0.28563417, -1.4048322 , -1.27095881],
#        [ 1.03001903,  0.06306209,  1.06109667,  1.58707463],
#        [ 0.31348405, -0.60465415,  0.55670212,  0.0281473 ],
#        [-1.0001634 , -1.71751454, -0.22791161, -0.23167392],
#        [-1.1195859 ,  0.06306209, -1.23670069, -1.40086942],
#        [-0.16420593, -1.04979831, -0.11582393, -0.23167392],
#        [ 1.26886402,  0.06306209,  0.6687898 ,  0.41787913],
#        [ 0.31348405, -1.04979831,  1.06109667,  0.28796852],
#        [-0.28362843, -0.82722623,  0.27648293,  0.15805791],
#        [ 2.10482149, -0.15950999,  1.62153504,  1.1973428 ],
#        [-0.88074091,  1.62106664, -1.01252534, -1.01113759],
#        [ 1.38828651,  0.28563417,  0.55670212,  0.28796852],
#        [-1.23900839,  0.06306209, -1.18065685, -1.27095881],
#        [-0.52247342,  1.84363872, -1.12461301, -1.01113759],
#        [-1.83612087, -0.15950999, -1.46087604, -1.40086942],
#        [ 0.55232904, -0.60465415,  0.78087748,  0.41787913],
#        [ 1.26886402,  0.28563417,  1.1171405 ,  1.45716402],
#        [ 0.55232904, -0.82722623,  0.6687898 ,  0.80761096],
#        [-0.88074091,  1.39849456, -1.23670069, -1.01113759],
#        [ 0.67175154,  0.28563417,  0.44461445,  0.41787913],
#        [-1.47785339,  0.06306209, -1.23670069, -1.27095881],
#        [-0.88074091,  0.50820625, -1.12461301, -0.88122698],
#        [ 0.31348405, -0.15950999,  0.6687898 ,  0.80761096],
#        [-1.71669838, -0.38208207, -1.29274453, -1.27095881],
#        [ 0.55232904,  0.50820625,  1.28527202,  1.71698524],
#        [ 1.62713151,  0.28563417,  1.28527202,  0.80761096],
#        [-0.04478344, -0.82722623,  0.10835142,  0.0281473 ],
#        [-0.88074091,  0.73077833, -1.23670069, -1.27095881],
#        [ 0.19406156, -1.94008662,  0.72483364,  0.41787913],
#        [ 0.19406156, -0.15950999,  0.61274596,  0.80761096],
#        [-0.04478344, -1.04979831,  0.16439526,  0.0281473 ],
#        [ 2.22424398, -1.04979831,  1.78966656,  1.45716402],
#        [ 1.03001903, -1.27237038,  1.17318434,  0.80761096],
#        [-1.0001634 , -2.38523078, -0.11582393, -0.23167392],
#        [ 1.8659765 , -0.60465415,  1.34131585,  0.93752157],
#        [-0.88074091,  0.9533504 , -1.29274453, -1.27095881],
#        [-0.16420593, -0.38208207,  0.27648293,  0.15805791],
#        [ 1.50770901, -0.15950999,  1.22922818,  1.1973428 ],
#        [-1.23900839,  0.73077833, -1.18065685, -1.27095881],
#        [-1.1195859 ,  0.06306209, -1.23670069, -1.40086942],
#        [-0.16420593,  2.95649911, -1.23670069, -1.01113759],
#        [ 1.03001903, -0.15950999,  0.72483364,  0.67770035],
#        [-0.88074091,  1.62106664, -1.18065685, -1.27095881],
#        [ 0.31348405, -0.15950999,  0.50065829,  0.28796852],
#        [-1.0001634 ,  1.17592248, -1.29274453, -1.27095881],
#        [ 0.55232904, -1.27237038,  0.6687898 ,  0.41787913],
#        [-0.40305092, -1.49494246, -0.00373626, -0.23167392],
#        [ 0.19406156,  0.73077833,  0.44461445,  0.54778974],
#        [-0.16420593, -0.60465415,  0.2204391 ,  0.15805791],
#        [ 1.746554  , -0.38208207,  1.45340353,  0.80761096],
#        [-1.0001634 , -0.15950999, -1.18065685, -1.27095881],
#        [ 1.03001903,  0.06306209,  0.38857061,  0.28796852],
#        [ 1.03001903,  0.50820625,  1.1171405 ,  1.71698524],
#        [ 0.43290655, -0.60465415,  0.61274596,  0.80761096],
#        [ 0.43290655,  0.73077833,  0.94900899,  1.45716402],
#        [ 0.67175154, -0.60465415,  1.06109667,  1.32725341],
#        [-0.16420593, -0.15950999,  0.27648293,  0.0281473 ],
#        [-0.40305092, -1.71751454,  0.16439526,  0.15805791],
#        [ 0.79117403, -0.15950999,  0.83692131,  1.06743219],
#        [ 1.26886402,  0.06306209,  0.94900899,  1.1973428 ],
#        [-0.04478344, -0.82722623,  0.2204391 , -0.23167392],
#        [ 0.79117403, -0.15950999,  1.17318434,  1.32725341],
#        [-0.76131841,  0.73077833, -1.29274453, -1.27095881],
#        [-1.0001634 ,  0.9533504 , -1.34878837, -1.1410482 ],
#        [-1.1195859 , -1.49494246, -0.22791161, -0.23167392],
#        [-1.0001634 ,  0.73077833, -1.23670069, -1.27095881],
#        [ 0.19406156, -1.94008662,  0.16439526, -0.23167392],
#        [-1.35843089,  0.28563417, -1.34878837, -1.27095881],
#        [-0.64189591,  1.39849456, -1.23670069, -1.27095881],
#        [-0.28362843, -0.60465415,  0.6687898 ,  1.06743219],
#        [-1.23900839, -0.15950999, -1.29274453, -1.40086942],
#        [-0.16420593, -1.27237038,  0.72483364,  1.06743219],
#        [ 0.67175154, -0.60465415,  1.06109667,  1.1973428 ],
#        [-0.76131841, -0.82722623,  0.10835142,  0.28796852],
#        [ 1.14944152, -0.60465415,  0.61274596,  0.28796852],
#        [ 0.55232904,  0.73077833,  1.06109667,  1.58707463],
#        [ 0.91059653, -0.38208207,  0.50065829,  0.15805791],
#        [-0.88074091, -1.27237038, -0.39604312, -0.10176331],
#        [-0.40305092,  0.9533504 , -1.34878837, -1.27095881],
#        [-0.40305092, -1.27237038,  0.16439526,  0.15805791],
#        [ 0.67175154,  0.28563417,  0.89296515,  1.45716402],
#        [-0.16420593,  1.62106664, -1.12461301, -1.1410482 ],
#        [-1.35843089,  0.28563417, -1.18065685, -1.27095881],
#        [ 0.31348405, -0.38208207,  0.55670212,  0.28796852],
#        [-1.47785339,  0.73077833, -1.29274453, -1.1410482 ],
#        [ 2.22424398,  1.62106664,  1.67757888,  1.32725341],
#        [ 2.46308898,  1.62106664,  1.50944737,  1.06743219],
#        [ 2.22424398, -0.15950999,  1.34131585,  1.45716402],
#        [ 0.79117403,  0.28563417,  0.78087748,  1.06743219],
#        [ 0.55232904,  0.50820625,  0.55670212,  0.54778974],
#        [-0.52247342,  1.84363872, -1.34878837, -1.01113759],
#        [-1.0001634 ,  0.50820625, -1.29274453, -1.27095881],
#        [-0.52247342, -0.15950999,  0.44461445,  0.41787913],
#        [-1.59727588, -1.71751454, -1.34878837, -1.1410482 ],
#        [ 1.03001903,  0.06306209,  0.55670212,  0.41787913],
#        [-0.40305092,  2.51135496, -1.29274453, -1.27095881],
#        [-1.0001634 ,  0.73077833, -1.18065685, -1.01113759],
#        [ 0.43290655, -1.94008662,  0.44461445,  0.41787913],
#        [-1.23900839,  0.73077833, -1.01252534, -1.27095881]])

# %%
X_test
# Out:
# array([[-1.47785339,  0.28563417, -1.29274453, -1.27095881],
#        [-1.23900839, -0.15950999, -1.29274453, -1.1410482 ],
#        [ 0.55232904, -1.27237038,  0.72483364,  0.93752157],
#        [ 0.07463906, -0.15950999,  0.78087748,  0.80761096],
#        [-1.71669838, -0.15950999, -1.34878837, -1.27095881],
#        [-1.1195859 ,  0.06306209, -1.23670069, -1.40086942],
#        [ 1.26886402,  0.06306209,  0.78087748,  1.45716402],
#        [-0.76131841,  0.9533504 , -1.23670069, -1.27095881],
#        [ 0.07463906, -0.15950999,  0.27648293,  0.41787913],
#        [-0.28362843, -1.27237038,  0.10835142, -0.10176331],
#        [-0.52247342,  0.73077833, -1.12461301, -1.27095881],
#        [-0.40305092, -1.04979831,  0.38857061,  0.0281473 ],
#        [ 0.31348405, -0.60465415,  0.16439526,  0.15805791],
#        [ 0.67175154, -0.82722623,  0.89296515,  0.93752157],
#        [ 0.79117403, -0.15950999,  1.00505283,  0.80761096],
#        [ 0.43290655, -0.38208207,  0.33252677,  0.15805791],
#        [ 0.67175154,  0.06306209,  1.00505283,  0.80761096],
#        [-0.16420593, -0.60465415,  0.44461445,  0.15805791],
#        [ 0.55232904, -0.38208207,  1.06109667,  0.80761096],
#        [ 0.79117403, -0.60465415,  0.50065829,  0.41787913],
#        [-1.1195859 , -1.27237038,  0.44461445,  0.67770035],
#        [-0.04478344, -0.82722623,  0.78087748,  0.93752157],
#        [ 0.55232904, -1.71751454,  0.38857061,  0.15805791],
#        [-1.47785339,  1.17592248, -1.51691988, -1.27095881],
#        [ 1.14944152,  0.28563417,  1.22922818,  1.45716402],
#        [ 1.62713151, -0.15950999,  1.17318434,  0.54778974],
#        [-0.88074091,  1.62106664, -1.23670069, -1.1410482 ],
#        [ 1.62713151,  1.17592248,  1.34131585,  1.71698524],
#        [ 0.19406156, -0.38208207,  0.44461445,  0.41787913],
#        [ 0.91059653, -0.15950999,  0.38857061,  0.28796852]])

# %%
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(X_train, y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
y_pred = classifier.predict(X_test)
y_pred
# Out:
# array(['setosa', 'setosa', 'virginica', 'virginica', 'setosa', 'setosa',
#        'virginica', 'setosa', 'versicolor', 'versicolor', 'setosa',
#        'versicolor', 'versicolor', 'virginica', 'virginica', 'versicolor',
#        'virginica', 'versicolor', 'virginica', 'versicolor', 'versicolor',
#        'virginica', 'versicolor', 'setosa', 'virginica', 'virginica',
#        'setosa', 'virginica', 'versicolor', 'versicolor'], dtype='<U10')

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[ 8,  0,  0],
#        [ 0, 10,  0],
#        [ 0,  1, 11]])

# %%
from sklearn.metrics import accuracy_score
print ("Accuracy : ", accuracy_score(y_test, y_pred))
# Out:
# Accuracy :  0.9666666666666667

# %%
df = pd.DataFrame({'Real Values':y_test, 'Predicted Values':y_pred})
df
# Out:
#    Real Values Predicted Values
# 0       setosa           setosa
# 1       setosa           setosa
# 2    virginica        virginica
# 3    virginica        virginica
# 4       setosa           setosa
# 5       setosa           setosa
# 6    virginica        virginica
# 7       setosa           setosa
# 8   versicolor       versicolor
# 9   versicolor       versicolor
# 10      setosa           setosa
# 11  versicolor       versicolor
# 12  versicolor       versicolor
# 13   virginica        virginica
# 14   virginica        virginica
# 15  versicolor       versicolor
# 16   virginica        virginica
# 17  versicolor       versicolor
# 18   virginica        virginica
# 19  versicolor       versicolor
# 20   virginica       versicolor
# 21   virginica        virginica
# 22  versicolor       versicolor
# 23      setosa           setosa
# 24   virginica        virginica
# 25   virginica        virginica
# 26      setosa           setosa
# 27   virginica        virginica
# 28  versicolor       versicolor
# 29  versicolor       versicolor
